# %% [markdown]
# ## Import modules

# %%
import pickle
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorchtools
import glob as gl
import random
import os
import time
import itertools

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.datasets import make_regression
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import log_loss
from numpy import hstack
from numpy import vstack

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Data loading

# %%
def find_directory(foldername, filename = None, back_num = 0):
    cur = os.getcwd()
    for i in range(back_num):
        cur = os.path.abspath(os.path.join(cur, os.pardir))
    for folder in foldername:
        cur = os.path.join(cur, folder)
    if not os.path.exists(cur):
        os.makedirs(cur)
        print(f'{cur} created')
    if filename != None:
        cur = os.path.join(cur, filename)
    return cur

os.getcwd()
find_directory(back_num = 1, foldername = ['Dataset'], filename = 'bat_dict.pkl')
# Out:
# 'C:\\Users\\User\\Desktop\\LIB\\CNN work\\Variable time length\\All dataset'
# 'C:\\Users\\User\\Desktop\\LIB\\CNN work\\Variable time length\\Dataset\\bat_dict.pkl'

# %%
bat_dict_add_1_2 = find_directory(back_num = 2, foldername = ['Dataset'], filename = 'bat_1_2_dict_VITQcQd.pkl')
with open(bat_dict_add_1_2, 'rb') as tf:
    bat_dict_1_2 = pickle.load(tf)

bat_sel_dict = bat_dict_1_2
max_time = 120

# %%
# Tensor dimension: (cell, cycle, time, variable)
num_cells = len(bat_sel_dict.keys())
regression_cycles = [45, 65, 85, 100]

# variable = [Qc, I, V, T, Qd]
num_variables = len(bat_sel_dict['b1c0']['1']['1.0'].keys())

for reg in regression_cycles:
    #'''RNN 가변길이 다룰수 있게?? 고민필요'''
    globals()[f'x_tensor_{reg}'] = torch.zeros(num_cells, reg, max_time, num_variables)
    cell_index = 1
    for cell in bat_sel_dict.keys():
        for cycle in range(1, reg+1):
            for time in bat_sel_dict[cell][str(cycle)].keys():
    #             print(bat_sel_dict[cell][str(cycle)][str(time)])
                value_list = [i for i in bat_sel_dict[cell][str(cycle)][str(time)].values()]
    #             print(value_list)
                globals()[f'x_tensor_{reg}'][cell_index-1, cycle-1, int(float(time)*max_time/60), :] = torch.FloatTensor(value_list)

        cell_index += 1

    globals()[f'x_tensor_{reg}'].size()

num_variables = x_tensor_100.shape[3]
time_length = x_tensor_100.shape[2]
# (cycle_index-1, cycle-1, time-1, variable(Qc, I, V, T, Qd))
# x_tensor[123, 99, 30, :]
# Out:
# torch.Size([124, 45, 120, 5])
# torch.Size([124, 65, 120, 5])
# torch.Size([124, 85, 120, 5])
# torch.Size([124, 100, 120, 5])

# %%
y_df_add = find_directory(back_num = 2, foldername = ['Dataset', 'y_df.csv'])
y_df = pd.read_csv(y_df_add)

# 2. Regression problem
# KO, KP, CL
y_cl_numpy = y_df['Cycle life'].to_numpy()
y_kp_numpy = y_df['kneepoints'].to_numpy()
y_ko_numpy = y_df['kneeonsets'].to_numpy()
# y_ko_numpy.shape

y_regression_numpy = y_ko_numpy

y_ko_tensor = torch.FloatTensor(y_ko_numpy)
y_ko_tensor.size()
# Out:
# torch.Size([124])

# %%
def setRandomSeed(random_seed=0):
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    torch.manual_seed(random_seed) # torch 
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
    torch.backends.cudnn.deterministic = True # cudnn
    torch.backends.cudnn.benchmark = False # cudnn
    np.random.seed(random_seed) # numpy
    random.seed(random_seed) # random

# %%
x_tensor_100.shape
# Out:
# torch.Size([124, 100, 120, 5])

# %% [markdown]
# ### Dataloading as 2D CNN's method

# %%
# y: no scaling
class dataPrep_RNN_CNN(Dataset):  
    def __init__(self, x_tensor, y_tensor, batch_size, scaler, purpose : str, test_split: float):
        setRandomSeed(random_seed = 100)
        self.xdata = torch.permute(x_tensor, (0, 3, 2, 1))
        self.ydata = y_tensor
        
        self.batch_size = batch_size
                
        self.xscaler = scaler()
        self.purpose = purpose
        
        self.test_split = test_split
        
        self.train_size, self.val_size, self.test_size = self.get_splits()
        
        # Tensor dimension: (cell, variable, time, cycle)
        # If problem emerges, check this part first.
        for i in range(len(self.xdata)):
            for j in range(self.xdata.shape[1]):
                temp = np.expand_dims(self.xscaler.fit_transform(self.xdata[i,j,:,:]), axis=0)
                if j ==0:
                    temp2 = temp
                else:
                    temp2 = np.vstack((temp2,temp))
            temp2 = np.expand_dims(temp2, axis=0)
            if i==0:
                self.xdata_scaled = temp2
            else:
                self.xdata_scaled = np.vstack((self.xdata_scaled, temp2))

        self.ydata_scaled = self.ydata
        
        self.x_train_scaled, self.x_test_scaled, self.y_train_scaled, self.y_test_scaled = train_test_split(self.xdata_scaled, 
                                                                                                            self.ydata_scaled, 
                                                                                                            test_size = self.test_size, 
                                                                                                            shuffle = True, 
                                                                                                            random_state=100)
        
        self.x_train_scaled, self.x_val_scaled, self.y_train_scaled, self.y_val_scaled = train_test_split(self.x_train_scaled,
                                                                                                         self.y_train_scaled,
                                                                                                         test_size = self.val_size, 
                                                                                                         shuffle = True, 
                                                                                                         random_state = 100)
        
        print(self.x_train_scaled.shape, self.x_val_scaled.shape, self.x_test_scaled.shape,
              self.y_train_scaled.shape, self.y_val_scaled.shape, self.y_test_scaled.shape)
        
        self.train = list(zip(self.x_train_scaled, self.y_train_scaled))
        self.val = list(zip(self.x_val_scaled, self.y_val_scaled))
        self.test = list(zip(self.x_test_scaled, self.y_test_scaled))
                
        self.train_dataloader = DataLoader(self.train, batch_size = self.batch_size, shuffle=True)
        self.val_dataloader = DataLoader(self.val, batch_size = self.batch_size, shuffle=True)
        self.test_dataloader = DataLoader(self.test, batch_size = self.batch_size, shuffle=True)
            
    # split the datasets into training and testing
    def get_splits(self):
        # test size
        test_size = int(self.test_split*len(self.xdata))
        # val size
        val_size = int(0.2*(len(self.xdata) - test_size))
        # train_size
        train_size = len(self.xdata) - val_size - test_size
        return train_size, val_size, test_size
    
    # Returns dataloaders for training and validation datasets
    def train_data(self):
        return self.train_dataloader, self.val_dataloader
    
    # Returns dataloader for test datasets
    def test_data(self):
        return self.test_dataloader
    
    def scaler(self, purpose):
#         if purpose != 'classification':
#             return self.xscaler, self.yscaler
#         else:
        return self.xscaler
    
    # finding length of x 
    def __len__(self):
        return len(self.X)
    
    # indexing rows for calling
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]

# %%
# reg_dataset = dataPrep1D(x_tensor, y_ko_tensor, batch_size = 16, scaler = MinMaxScaler, purpose = 'regression', test_split = 0.2)
# reg_train_dataloader, reg_val_dataloader = reg_dataset.train_data()
# reg_test_dataloader = reg_dataset.test_data()
# reg_xscaler = reg_dataset.scaler('regression')

regression_cycles = [45, 65, 85, 100]
# regression_cycles = [100]


# x와 y가 1대1 대응이어야 dataloader를 만들 수 있어서 2D array 그대로 놓고 학습시 tensor transform 예정
for reg in regression_cycles:
    globals()[f'reg_dataset_{reg}'] = dataPrep_RNN_CNN(globals()[f'x_tensor_{reg}'], y_ko_tensor, batch_size = 4, scaler = MinMaxScaler, purpose =  'regression', test_split = 0.2)
    globals()[f'reg_train_dataloader_{reg}'], globals()[f'reg_val_dataloader_{reg}'] = globals()[f'reg_dataset_{reg}'].train_data()
    globals()[f'reg_test_dataloader_{reg}'] = globals()[f'reg_dataset_{reg}'].test_data()
    globals()[f'reg_xscaler_{reg}'] = globals()[f'reg_dataset_{reg}'].scaler('regression')
# Out:
# (80, 5, 120, 45) (20, 5, 120, 45) (24, 5, 120, 45) torch.Size([80]) torch.Size([20]) torch.Size([24])
# (80, 5, 120, 65) (20, 5, 120, 65) (24, 5, 120, 65) torch.Size([80]) torch.Size([20]) torch.Size([24])
# (80, 5, 120, 85) (20, 5, 120, 85) (24, 5, 120, 85) torch.Size([80]) torch.Size([20]) torch.Size([24])
# (80, 5, 120, 100) (20, 5, 120, 100) (24, 5, 120, 100) torch.Size([80]) torch.Size([20]) torch.Size([24])

# %%
# train_features, train_labels = next(iter(cla_train_dataloader))
# print(f"Classification case_Inputs batch shape(Batch size, num_vars, timestep, cycles): {train_features.size()}")
# print(f"Classification case_Outputs batch shape(Batch size): {train_labels.size()}")

reg = 100
train_features, train_labels = next(iter(globals()[f'reg_train_dataloader_{reg}']))
print(f'reg = {reg}')
print(f"Regression case_Inputs batch shape(Batch size, num_vars, timestep, cycles): {train_features.size()}")
print(f"Regression case_Outputs batch shape(Batch size): {train_labels.size()}")

train_features.float().type()
# Out:
# reg = 100
# Regression case_Inputs batch shape(Batch size, num_vars, timestep, cycles): torch.Size([4, 5, 120, 100])
# Regression case_Outputs batch shape(Batch size): torch.Size([4])
# 'torch.FloatTensor'

# %% [markdown]
# ## Define Model Class

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class RNNcell(nn.Module):
    def __init__(self, model, input_size, hidden_size, dropout = 0.1, bidirectional = False, num_layer=1):
        super(RNNcell, self).__init__()
        
        if torch.cuda.is_available():
            self.device = 'cuda'
        else:
            self.device = 'cpu'
            
        self.model = model
        self.hidden_size = hidden_size
        self.num_layer = num_layer
        self.bidirectional = bidirectional
        
        self.D = 1 + self.bidirectional
        self.batch_size = 4
        
        #Batch size * cycles, timestep, input_size
        if self.model.endswith('RNN'):
            self.rnn = nn.RNN(input_size, hidden_size, num_layer, batch_first = True, dropout = dropout, bidirectional = bidirectional).to(self.device)
        elif self.model.endswith('LSTM'):
            self.rnn = nn.LSTM(input_size, hidden_size, num_layer, batch_first = True, dropout = dropout, bidirectional = bidirectional).to(self.device)
        elif self.model.endswith('GRU'):
            self.rnn = nn.GRU(input_size, hidden_size, num_layer, batch_first = True, dropout = dropout, bidirectional = bidirectional).to(self.device)
            
        for name, param in self.rnn.named_parameters():
            if name.startswith('weight'):
                nn.init.xavier_uniform(param)
            else:
                nn.init.normal(param)
        
    def forward(self, x):
        # x made from (cell * n_cy, timestep(seq_len), num_vars)
        self.batch_size = x.size(0)
        
        D = 1 + self.bidirectional
        #out: Containing output features h_t from the last layer of LSTM for each t(if bidirectional ==True: concat of forward and backward hidden states)
        #h_n: Containing final hidden state in the sequence
        h0 = torch.zeros(D*self.num_layer, self.batch_size, self.hidden_size).to(self.device)
        if self.model.endswith('LSTM'):
            c0 = torch.zeros(D*self.num_layer, self.batch_size, self.hidden_size).to(self.device)
            # c_n: Containing final cell state in the sequence
            out, (hn, cn) = self.rnn(x, (h0, c0))
        else:
            out, hn = self.rnn(x, h0.detach())
        return out, hn

# %%
class RNN_TA_1DCNN(nn.Module):
    def __init__(self, input_size, num_time, num_cycles, rnn1, bi1, hid1, fil2, pool2, npool2, fsize2, psize2, mids, dr1 = 0.1, dr2 = 0.1, di2 = 1, st2 = 1, pad2 = 0):
        super(RNN_TA_1DCNN, self).__init__()
        setRandomSeed()
        
        self.D1 = 1 + bi1
        
        self.rnn1 = RNNcell(rnn1, input_size, hid1, dr1, bi1)
        
        if torch.cuda.is_available():
            self.device = 'cuda'
        else:
            self.device = 'cpu'
        
        # Overall parameters
        self.num_time = num_time
        self.num_cycles = num_cycles
        self.mids = mids
        
        # Pooling/Nonpooling parameters
        self.pool2 = pool2
        self.npool2 = npool2
        # Pooling size(Pooling layer)
        self.psize2 = psize2
        
        # CNN hyperparameters
        self.fil2 = fil2
        self.fsize2 = fsize2
        self.di2 = di2
        self.st2 = st2
        # Padding for CNN
        self.pad2 = pad2
                
        # Critical values for the 1st CNN layer
        # Batch for different cells
        
        # Conv1d takes input dimension: [Batch_size, c_in(no. of in_channels )= hidden_size, l_in = num_cycles]
        self.in2 = self.D1*hid1
        self.out2 = self.fil2
        self.Lout = self.num_cycles
        
        # Conv_block1~P
        # Pooling layers
        for i in range(1, self.pool2+1):
#             print(f"i: {i}, out_channels: {self.out_channels}")
            globals()[f'self.conv_block{i}'] = nn.Sequential(
            nn.Conv1d(self.in2, self.out2, self.fsize2, self.st2, self.pad2),
            nn.BatchNorm1d(self.out2),
            nn.ReLU(),
            nn.MaxPool1d(self.psize2)
            ).to(self.device)

            self.in2 = self.out2
            self.out2 = self.out2*2
            self.Lout = int(int((self.Lout+2*self.pad2-self.di2*(self.fsize2-1)-1)/self.st2+1)/self.psize2)

        for j in range(self.pool2+1, self.pool2+self.npool2+1):
            globals()[f'self.conv_block{j}'] = nn.Sequential(
            nn.Conv1d(self.in2, self.out2, self.fsize2, self.st2, self.pad2),
            nn.BatchNorm1d(self.out2),
            nn.ReLU(),
            ).to(self.device)
            
            self.in2 = self.out2
            self.out2 = self.out2*2
            self.Lout = int((self.Lout+2*self.pad2-self.di2*(self.fsize2-1)-1)/self.st2+1)
        
        self.lin1 = nn.Linear(self.D1*hid1, 1)
        self.sm1 = nn.Softmax(dim = 2)
        self.relu = nn.ReLU()
        
        self.fc = nn.Sequential(nn.Linear(self.in2*self.Lout, self.mids[0], bias=True), nn.ReLU(),
                       nn.Linear(self.mids[0], self.mids[1], bias = True), nn.ReLU(),
                       nn.Linear(self.mids[1], self.mids[2], bias = True))
        
        self.fc.apply(self.init_weights)
        
    def init_weights(self, m):
        self.m = m
        if type(self.m) == nn.Linear:
            nn.init.xavier_uniform_(self.m.weight)
        
    def forward(self, x):
        # Original: Batch size, num_vars, timestep, cycles=>Batch size * cycles, timestep, input_size
        x = torch.reshape(x, (x.size(0)*x.size(3), x.size(2), x.size(1))).to(device)
#         print("Batch size * cycles, timestep, input_size: ", x.size())
        out1, hn1 = self.rnn1(x)
        
        # hn의 batch size가 n_cy*k로 설정
        cell_batch_size = int(hn1.size(1)/self.num_cycles)

        # Reshape for input
        # out1: (batch_size = num_cell*num_cycle, timestep, D1*hid1)
        # outs : (batch_size(num_cell), num_cycle, timestep, D1*hid1)
        outs1 = torch.reshape(out1, (cell_batch_size, -1, out1.size(1), out1.size(2)))
        # ta: (batch_size, num_cycle, timestep, 1(D1*hid1->1))
        ta = self.sm1(self.lin1(outs1))
        # ta_outs: (batch_size, num_cycle, timestep, D1*hid1)=>(batch_size, D1*hid1, num_cycle, timestep)
        ta_outs = torch.permute(ta*outs1, (0, 3, 1, 2))
        # ct_vec: (batch_size, D1*hid1, num_cycle)
        ct_vec = torch.sum(ta_outs, -1)
        
        # input for 1d cnn: (batch_size, D1*hid1, num_cycle)
        for i in range(1, self.pool2+self.npool2+1):
            ct_vec = globals()[f'self.conv_block{i}'](ct_vec)
        # ct_vec from final convolutional layer: (batch_size, self.in2*self.Lout)
        ct_vec = ct_vec.view(ct_vec.size(0), -1)
        # final_out: (batch_size, 1)
        final_out = self.fc(ct_vec)
        
        return final_out.squeeze(), ta.squeeze()

# %%
# Function for saving and loading of training history
def save_data(D3_array, filename):
    with open(filename,"wb") as dat_:
        pickle.dump(D3_array,dat_)
        
def load_data(filename):
    with open(filename,"rb") as ld:
        x_temp = pickle.load(ld)
    return x_temp

# Early stopping class
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.best_epoch = 1
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, epoch, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.best_model = self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
#             print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.best_epoch = epoch
            self.best_model = self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'At epoch {self.best_epoch}: Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        return model

# %%
class train:
    def __init__(self, model: nn.Module, train_dataloader, val_dataloader, test_dataloader, epoch: int, learning_rate=0.01, patience = 5, verbose = False):
        super().__init__()
        #   Reprocudtion
        setRandomSeed(100)
        random_seed = 100
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(random_seed)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False
        os.environ['PYTHONHASHSEED'] = str(random_seed)
        torch.manual_seed(random_seed)
        np.random.seed(random_seed)

        if torch.cuda.is_available():
            self.device = 'cuda'
        else:
            self.device = 'cpu'
        
        self.model = model.to(self.device)
        self.train_dataloader = train_dataloader
        self.val_dataloader = val_dataloader
        self.test_dataloader = test_dataloader
        self.epoch = epoch
        self.learning_rate = learning_rate
        
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr = self.learning_rate)
        self.early_stopping = EarlyStopping(patience = patience, verbose = verbose)

        self.criterion = nn.MSELoss()
        self.name = ['train_rmse', 'val_rmse', 'test_rmse']
        
    def EvalModel(self):
        EvalPredictions, EvalActuals = list(), list()
        TestPredictions, TestActuals = list(), list()
        self.model.eval()
        with torch.no_grad():
            for n, (inputs, targets) in enumerate(self.val_dataloader):
                inputs = inputs.float().to(self.device)
                targets = targets.float().to(self.device)

                yhat, ta = self.model(inputs)

                if self.device !='cpu':
                    yhat = yhat.to('cpu')
                    targets = targets.to('cpu')    

                yhat = yhat.detach().numpy()
                actual = targets.numpy()
                EvalPredictions.append(yhat)
                EvalActuals.append(actual)

            EvalPredictions, EvalActuals = vstack(EvalPredictions), vstack(EvalActuals)
            val_rmse = mean_squared_error(EvalActuals, EvalPredictions, squared = False)
            
            for n, (inputs, targets) in enumerate(self.test_dataloader):
                inputs = inputs.float().to(self.device)
                targets = targets.float().to(self.device)

                yhat, ta = self.model(inputs)

                if self.device !='cpu':
                    yhat = yhat.to('cpu')
                    targets = targets.to('cpu')    

                yhat = yhat.detach().numpy()
                actual = targets.numpy()
                TestPredictions.append(yhat)
                TestActuals.append(actual)

            TestPredictions, TestActuals = vstack(TestPredictions), vstack(TestActuals)
            test_rmse = mean_squared_error(TestActuals, TestPredictions, squared = False)
            
            return val_rmse, test_rmse

    def TrainModel(self):
        loss_history = []
        self.model.train()
        for i in range(self.epoch):
            predictions, actuals = list(), list()
            for n, (inputs, targets) in enumerate(self.train_dataloader):
                self.model.train()
                inputs = inputs.float().to(self.device)
                targets = targets.float().to(self.device)

                self.optimizer.zero_grad()

                yhat, ta = self.model(inputs)
                    
                loss = self.criterion(yhat, targets)
                loss.backward()
                self.optimizer.step()
                
                if self.device !='cpu':
                    yhat = yhat.to('cpu')
                    targets = targets.to('cpu')
                    
                yhat = yhat.detach().numpy()
                predictions.append(yhat)
                
                targets = targets.numpy()
                actuals.append(targets)

            # evaluation of entire train data
            predictions, actuals = vstack(predictions), vstack(actuals)
            
            train_rmse = mean_squared_error(actuals, predictions, squared = False)

            # evaluation on validation data
            val_rmse, test_rmse = self.EvalModel()
            early_factor = val_rmse
            
            # training loss history
            loss_history.append([train_rmse, val_rmse, test_rmse])

            self.early_stopping(i+1, early_factor, self.model)
            
            if self.early_stopping.early_stop:
                print("Early stopping at best epoch: ", self.early_stopping.best_epoch)
                self.best_loss = loss_history[self.early_stopping.best_epoch-1]
                loss_history = loss_history[:self.early_stopping.best_epoch]
                
                return self.model, self.best_loss, pd.DataFrame(loss_history, columns = self.name), ta
            
        print(f"Ends at final epoch {self.epoch}")
        print(f"Best epoch: {self.early_stopping.best_epoch}")
        self.best_loss = loss_history[self.early_stopping.best_epoch-1]
        loss_history = loss_history[:self.early_stopping.best_epoch]
        
        return self.model, self.best_loss, pd.DataFrame(loss_history, columns = self.name), ta
        
    def predict(self, data: torch.Tensor):
        return self.model(data)
    
    def train_val_test_plot_rmse(self, num_cycles, modelname, n_ep, patience, rnn1, hid1, fil2, pool2, npool2, fsize2, psize2, lr):
        dataloaders = [self.train_dataloader, self.val_dataloader, self.test_dataloader]

        with torch.no_grad():
            model.eval()

            model_rmse = list()
            dset_index = 0
            for dataloader in dataloaders:
                if dset_index ==0:
                    dset = 'train'
                elif dset_index == 1:
                    dset = 'val'
                else:
                    dset = 'test'

                figadd = find_directory(back_num = 0, foldername = [f'{num_cycles} cycles', f'Depth Test_col_{n_ep}_{patience}', modelname, f'{rnn1}_1D CNN', 'train_history'], 
                                             filename = f'{rnn1}_hidden_{hid1}_n_fil_{fil2}_pool_{pool2}_npool_{npool2}_fsize_{fsize2}_psize_{psize2}_lr_1_{int(1/lr)}.jpg')

                predictions, actuals = list(), list()
                for i, (test_input, test_target) in enumerate(dataloader):
                    test_input = test_input.float().to(self.device)
                    test_target = test_target.float().to(self.device)
                    test_yhat, test_ta = model(test_input)

                    if self.device != 'cpu':
                        test_yhat = test_yhat.to('cpu')
                        test_target = test_target.to('cpu')

                    test_yhat = test_yhat.detach().tolist()
                    predictions += test_yhat
                    test_target = test_target.tolist()
                    actuals += test_target

                pred_acc, targ_acc = np.array(predictions), np.array(actuals)

                rmse = mean_squared_error(actuals, predictions, squared = False)
                model_rmse.append(rmse)

                plt.figure(figsize=[10,4])
                plt.rcParams["font.size"] = "12"
                plt.plot(pred_acc, label='Prediction')
                plt.plot(range(len(targ_acc)), targ_acc, label = 'Actual')
                plt.xticks(range(0, len(targ_acc) + 1, int(len(targ_acc)/5)))
                plt.title(f"{rnn1}_hid_{hid1}_nfil_{fil2}_pool_{pool2}_npool_{npool2}_fsize_{fsize2}_psize_{psize2}: RMSE={rmse}")
                plt.xlabel('cell')
                plt.ylabel('Lifespan(cycle)')
                plt.legend()
                plt.savefig(figadd)
                plt.close()

                dset_index += 1

        return model_rmse

# %% [markdown]
# ## Implementation

# %%
def history_state_dict_add(num_cycles, modelname, n_ep, patience, rnn1, hid1, fil2, pool2, npool2, fsize2, psize2, lr):
    history_add = find_directory(back_num = 0, foldername = [f'{num_cycles} cycles', f'Depth Test_col_{n_ep}_{patience}', modelname, f'{rnn1}_1D CNN', 'train_history'], 
                                             filename = f'{rnn1}_hidden_{hid1}_n_fil_{fil2}_pool_{pool2}_npool_{npool2}_fsize_{fsize2}_psize_{psize2}_lr_1_{int(1/lr)}.pkl')
    state_dict_add = find_directory(back_num = 0, foldername = [f'{num_cycles} cycles', f'Depth Test_col_{n_ep}_{patience}', modelname, f'{rnn1}_1D CNN', 'model'], 
                                             filename = f'{rnn1}_hidden_{hid1}_n_fil_{fil2}_pool_{pool2}_npool_{npool2}_fsize_{fsize2}_psize_{psize2}_lr_1_{int(1/lr)}_state_dict.pth')
    ta_add = find_directory(back_num = 0, foldername = [f'{num_cycles} cycles', f'Depth Test_col_{n_ep}_{patience}', modelname, f'{rnn1}_1D CNN', 'ta'],
                                             filename = f'{rnn1}_hidden_{hid1}_n_fil_{fil2}_pool_{pool2}_npool_{npool2}_fsize_{fsize2}_psize_{psize2}_lr_1_{int(1/lr)}_ta.wb')
    return history_add, state_dict_add, ta_add

# %%
# Hyperparameters
num_vars = train_features.size()[1]

modelname = 'RNN_TA_1DCNN'
rnns = ['LSTM', 'GRU', 'RNN']
hids = [3, 5, 7]
num_time = max_time
num_cycles = 100
ep_pats = [[1000, 10], [2000, 20], [3000, 500]]
lrs = [1e-4, 1e-3, 1e-2]

num_fils = [3, 5, 7]
pools = [1, 2]
npools = [1, 2]
fsize2 = 3
psize2 = 2
mids = [8, 4, 1]

import time

for [n_ep, patience] in ep_pats:
    print(f"epoch = {n_ep}, patience = {patience}")
    trdl = globals()[f'reg_train_dataloader_{num_cycles}']
    vdl = globals()[f'reg_val_dataloader_{num_cycles}']
    tedl = globals()[f'reg_test_dataloader_{num_cycles}']
    for rnn1, hid1 in itertools.product(rnns, hids):
        bi1 = False
        if rnn1.startswith('Bi'):
            bi1 = True
        for pool2, npool2 in itertools.product(pools, npools):
            print(f'Pooling: {pool2} layers, Nonpooling: {npool2} layers, split by {60/max_time} min')
            for fil2, lr in itertools.product(num_fils, lrs):
                start = time.time()
                print(f"rnn = {rnn1}, bi = {bi1}, hid = {hid1}, num_fil = {fil2}, lr = {lr}")
                
                # Construct CNN
                model = globals()[modelname](num_vars, num_time, num_cycles, rnn1, bi1, hid1, fil2, pool2, npool2, fsize2, psize2, mids).to(device)

                # Train
                model_train = train(model, trdl, vdl, tedl, n_ep, lr, patience, verbose = False)
                best_model, best_loss, history, ta = model_train.TrainModel()

                print('best_loss = '+ str(best_loss))

                history_add, state_dict_add, ta_add = history_state_dict_add(num_cycles, modelname, n_ep, patience,
                                                                            rnn1, hid1, fil2, pool2, npool2, fsize2, psize2, lr)
                
                # saving best_epoch, loss history, ta score
                save_data(history, history_add)
                save_data(best_model.state_dict(), state_dict_add)
                save_data(ta, ta_add)

                print("time: ", time.time()-start)
                print("\n\n")
# Out:
# epoch = 1000, patience = 10
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  13
# best_loss = [577.79425, 542.3338, 522.103]
# time:  4.199462413787842
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  33
# best_loss = [255.0834, 172.3768, 120.02615]
# time:  4.1010048389434814
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  33
# best_loss = [153.60907, 98.18982, 72.558174]
# time:  4.0960047245025635
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [254.86148, 179.30984, 130.96541]
# time:  16.36801838874817
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [261.13672, 170.90521, 115.49716]
# time:  2.8750030994415283
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  29
# best_loss = [131.26959, 107.64154, 85.948685]
# time:  3.736004114151001
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.198, 543.8063, 528.30493]
# time:  1.4440016746520996
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [222.19186, 126.55438, 92.04769]
# time:  6.829007625579834
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [115.46452, 116.557556, 63.824463]
# time:  4.512005090713501
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.5054, 544.13007, 528.667]
# time:  1.5290014743804932
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [241.52719, 166.75131, 113.74437]
# time:  4.719005823135376
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  48
# best_loss = [117.14318, 121.58365, 107.18346]
# time:  6.008588790893555
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [267.9343, 196.08644, 147.2873]
# time:  17.750683307647705
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [231.44876, 159.5289, 103.21138]
# time:  4.762005567550659
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [132.39354, 120.356964, 77.351585]
# time:  4.86353874206543
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [272.3683, 199.91965, 154.23094]
# time:  17.626054286956787
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [231.44418, 158.94159, 106.63924]
# time:  4.7440056800842285
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  22
# best_loss = [128.11337, 98.26353, 58.582077]
# time:  3.283003568649292
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.38763, 544.0619, 528.5898]
# time:  1.5240018367767334
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [236.12936, 146.78783, 114.33212]
# time:  7.225047588348389
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [221.489, 152.5025, 94.6733]
# time:  2.119002103805542
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [290.72214, 217.54182, 169.53093]
# time:  17.384174823760986
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [261.16275, 159.56668, 117.34252]
# time:  3.0630037784576416
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  28
# best_loss = [127.102264, 114.40738, 70.94729]
# time:  3.852004289627075
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.2278, 543.8891, 528.41156]
# time:  1.5240018367767334
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.1587, 543.8069, 528.32855]
# time:  1.5280015468597412
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.4687, 542.98535, 527.4987]
# time:  1.5330016613006592
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.4037, 544.07605, 528.5891]
# time:  1.613002061843872
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.312, 543.97107, 528.4944]
# time:  1.607001543045044
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.62195, 543.14954, 527.66455]
# time:  1.608001708984375
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.69135, 544.37866, 528.90753]
# time:  1.6720020771026611
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.5655, 544.23694, 528.76294]
# time:  1.672001838684082
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.8409, 543.3839, 527.90125]
# time:  1.674001693725586
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  150
# best_loss = [232.14073, 163.1722, 122.31774]
# time:  17.982028245925903
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [216.15834, 143.4371, 98.650566]
# time:  5.1820056438446045
#
#
#
# rnn = LSTM, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  31
# best_loss = [119.045074, 141.70328, 98.25679]
# time:  4.599005222320557
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.00757, 543.5873, 528.10925]
# time:  1.4380016326904297
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [244.52486, 157.5837, 119.83788]
# time:  4.427005052566528
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [229.82336, 160.5566, 114.49744]
# time:  2.0190024375915527
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.3109, 543.92163, 528.44916]
# time:  1.4440014362335205
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [247.21088, 163.81715, 115.45502]
# time:  5.584006309509277
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  31
# best_loss = [144.08524, 114.30844, 62.928886]
# time:  3.9410042762756348
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  185
# best_loss = [242.24883, 173.74025, 115.237076]
# time:  18.83902144432068
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [220.78905, 145.3478, 88.93268]
# time:  4.467004776000977
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  16
# best_loss = [154.53967, 98.02805, 70.81291]
# time:  2.5040032863616943
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [258.17795, 188.64842, 141.52586]
# time:  17.49501943588257
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [254.04684, 164.38748, 121.26614]
# time:  3.0700035095214844
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  27
# best_loss = [130.6862, 117.740265, 72.77329]
# time:  3.786004066467285
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  162
# best_loss = [226.64032, 155.59, 117.198906]
# time:  17.738020181655884
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [243.07227, 150.54135, 102.28107]
# time:  3.1160037517547607
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  22
# best_loss = [142.7456, 110.95662, 78.38164]
# time:  3.3040034770965576
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.06226, 543.5937, 528.1134]
# time:  1.548001766204834
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [571.94165, 543.5554, 528.074]
# time:  1.554001808166504
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  99
# best_loss = [286.43658, 214.47859, 159.54147]
# time:  11.24201250076294
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.4739, 544.1673, 528.68964]
# time:  1.5160017013549805
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.3507, 544.0125, 528.53625]
# time:  1.5230016708374023
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.6607, 543.191, 527.70636]
# time:  1.5210018157958984
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.145, 543.6959, 528.31995]
# time:  1.5360016822814941
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [234.28745, 160.74313, 132.33626]
# time:  4.710005283355713
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [203.91425, 143.83208, 116.529655]
# time:  2.5530028343200684
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [555.53125, 513.12726, 501.36993]
# time:  4.176004886627197
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [228.48508, 157.72256, 111.52732]
# time:  4.701005220413208
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [212.31165, 136.16315, 78.7042]
# time:  2.1440021991729736
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.9222, 543.3962, 527.9763]
# time:  1.616001844406128
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [234.19507, 156.93274, 127.77107]
# time:  4.96500563621521
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [188.84515, 144.49457, 102.364105]
# time:  2.6910030841827393
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [560.6312, 518.7168, 507.252]
# time:  4.609004974365234
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [233.06287, 147.05313, 119.5266]
# time:  5.1920061111450195
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  19
# best_loss = [166.66515, 114.35827, 65.25773]
# time:  3.280003786087036
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  185
# best_loss = [241.61935, 174.808, 120.786026]
# time:  22.072024822235107
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [221.9277, 146.21222, 100.60892]
# time:  5.119005918502808
#
#
#
# rnn = LSTM, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [168.24535, 128.88745, 89.21202]
# time:  3.4030039310455322
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.66675, 544.3416, 528.839]
# time:  1.46700119972229
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [244.59703, 162.60156, 114.3333]
# time:  4.459005117416382
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  12
# best_loss = [229.07758, 149.76906, 99.905304]
# time:  2.128002405166626
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.8978, 543.47406, 527.98804]
# time:  1.4490022659301758
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  64
# best_loss = [224.66049, 140.00006, 90.74609]
# time:  7.170007228851318
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [213.39268, 129.36517, 65.7647]
# time:  2.0290024280548096
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  143
# best_loss = [258.27536, 174.34595, 126.17911]
# time:  14.791016578674316
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [249.11166, 162.2189, 114.979195]
# time:  2.90700364112854
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  19
# best_loss = [152.57916, 87.21028, 63.27587]
# time:  2.815002918243408
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.21387, 543.81116, 528.3665]
# time:  1.5370018482208252
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [266.6715, 171.63132, 140.51016]
# time:  3.0770034790039062
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [137.68367, 104.29384, 78.78983]
# time:  4.854005336761475
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  150
# best_loss = [234.70428, 177.98557, 123.492645]
# time:  16.685522079467773
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [183.73807, 123.411606, 63.89416]
# time:  7.308008193969727
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  14
# best_loss = [165.39206, 109.90292, 79.41668]
# time:  2.4730026721954346
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [233.07056, 158.56229, 111.63206]
# time:  17.659523248672485
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [242.82355, 152.58498, 105.00872]
# time:  3.102003574371338
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  14
# best_loss = [171.19809, 127.12317, 78.10915]
# time:  2.4830026626586914
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [569.71045, 540.94604, 525.79645]
# time:  1.5190017223358154
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [195.97237, 114.26332, 76.84963]
# time:  7.200008153915405
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [181.15985, 121.45967, 66.41593]
# time:  2.517002820968628
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [570.5026, 541.8273, 526.3355]
# time:  1.5350017547607422
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [235.59827, 147.18747, 94.68243]
# time:  5.925006628036499
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  12
# best_loss = [214.84933, 135.47815, 87.54595]
# time:  2.251002550125122
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [239.81538, 174.6963, 130.32187]
# time:  17.367019414901733
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [244.08383, 167.05266, 124.345085]
# time:  3.0610039234161377
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [151.09386, 117.39169, 74.664055]
# time:  3.0570027828216553
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [246.711, 180.7821, 135.81708]
# time:  18.378736972808838
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [242.108, 152.26465, 120.27904]
# time:  3.232003927230835
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [181.60162, 126.95009, 70.60702]
# time:  2.2640023231506348
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  185
# best_loss = [243.05731, 177.62448, 124.22484]
# time:  21.743024587631226
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [228.37535, 155.59671, 104.47152]
# time:  5.145005464553833
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [113.98706, 136.9898, 75.09352]
# time:  5.236006021499634
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  99
# best_loss = [257.24918, 191.55959, 129.7293]
# time:  12.262013673782349
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [238.001, 148.2473, 85.53671]
# time:  3.378004312515259
#
#
#
# rnn = LSTM, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [162.5414, 129.68832, 66.23425]
# time:  2.364002227783203
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.62024, 543.1565, 527.6791]
# time:  1.42427396774292
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [230.20004, 155.80917, 120.2655]
# time:  4.369866371154785
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  38
# best_loss = [131.11504, 91.08504, 71.449394]
# time:  4.558305025100708
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [561.09564, 519.1696, 507.6897]
# time:  3.8940043449401855
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [245.21036, 163.66269, 117.280846]
# time:  4.389004945755005
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  46
# best_loss = [139.04414, 115.972115, 83.78924]
# time:  5.322795867919922
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  143
# best_loss = [255.29065, 174.04776, 115.90343]
# time:  14.603642702102661
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  41
# best_loss = [227.99951, 152.79617, 96.95242]
# time:  4.91100549697876
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [158.3995, 128.31517, 64.58312]
# time:  2.404326915740967
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [570.26776, 541.5712, 526.10205]
# time:  1.5330018997192383
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [227.18774, 148.58278, 97.69713]
# time:  5.923810243606567
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  19
# best_loss = [171.91373, 143.27904, 102.78424]
# time:  2.893002986907959
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.2109, 543.8677, 528.3887]
# time:  1.5060017108917236
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.1373, 543.784, 528.3054]
# time:  1.5090017318725586
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.4474, 542.9625, 527.4756]
# time:  1.5140016078948975
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.9139, 544.62286, 529.15436]
# time:  1.4990017414093018
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.84393, 544.54065, 529.0697]
# time:  1.5020017623901367
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [572.1537, 543.71893, 528.2397]
# time:  1.4980015754699707
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.8754, 543.4804, 527.9978]
# time:  1.5080020427703857
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [243.12482, 167.04185, 119.125725]
# time:  4.620703935623169
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [235.58348, 151.20905, 96.32882]
# time:  2.1070022583007812
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.9085, 543.51404, 528.00806]
# time:  1.484163761138916
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [248.98012, 156.23737, 115.652466]
# time:  5.760006666183472
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [198.27124, 143.91678, 100.546486]
# time:  2.4770026206970215
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [557.5763, 515.05347, 503.5052]
# time:  4.046004772186279
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [226.14929, 155.02751, 112.006165]
# time:  4.55300498008728
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [180.39621, 137.45325, 80.64667]
# time:  2.968003273010254
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [263.61227, 199.84866, 143.27815]
# time:  18.023804903030396
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [251.37357, 163.41714, 119.617645]
# time:  3.171003818511963
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  25
# best_loss = [133.46692, 120.935104, 96.20369]
# time:  3.6920039653778076
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  143
# best_loss = [252.45964, 171.37738, 122.4625]
# time:  16.70801877975464
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [238.80655, 160.78442, 103.74846]
# time:  3.292003870010376
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [153.35529, 112.149704, 65.31378]
# time:  2.7330029010772705
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.587, 544.2799, 528.8421]
# time:  1.6680018901824951
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.5113, 544.18445, 528.7099]
# time:  1.667001724243164
#
#
#
# rnn = GRU, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  31
# best_loss = [126.721504, 116.01638, 68.71869]
# time:  4.548005104064941
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [563.26514, 521.65, 509.876]
# time:  3.8450045585632324
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [237.7181, 166.58907, 120.76318]
# time:  4.324004888534546
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [191.43568, 131.9145, 84.75076]
# time:  2.3460023403167725
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [570.82916, 542.20526, 526.7062]
# time:  1.4120018482208252
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [249.9412, 164.13138, 109.39697]
# time:  4.332005023956299
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  14
# best_loss = [153.8451, 124.25212, 73.27257]
# time:  2.2610023021698
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  150
# best_loss = [238.84973, 182.30591, 123.34787]
# time:  15.095016956329346
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [255.08778, 164.70724, 112.60118]
# time:  2.843003273010254
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  36
# best_loss = [120.14244, 116.630035, 77.96338]
# time:  4.339004993438721
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [556.1077, 513.6473, 502.17645]
# time:  4.0920045375823975
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [258.0163, 162.16284, 110.494804]
# time:  3.016003370285034
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [192.37422, 134.66959, 88.28408]
# time:  2.1040027141571045
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.27466, 542.81085, 527.3202]
# time:  1.5120012760162354
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [229.92288, 161.0373, 113.305885]
# time:  4.643005132675171
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  38
# best_loss = [126.58272, 107.55507, 67.14063]
# time:  4.828005790710449
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  98
# best_loss = [240.01959, 166.91116, 107.97441]
# time:  10.810012102127075
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [225.70538, 143.87682, 86.12091]
# time:  3.0070033073425293
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [134.31813, 100.86896, 101.94763]
# time:  2.511002779006958
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.3341, 543.95325, 528.4943]
# time:  1.5110018253326416
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [245.68442, 150.37695, 129.428]
# time:  7.147007942199707
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [186.32245, 116.804184, 73.90196]
# time:  3.019003391265869
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [243.43346, 175.1705, 123.17938]
# time:  16.97701930999756
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [249.87175, 154.21107, 110.50249]
# time:  2.9830031394958496
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  38
# best_loss = [105.19385, 121.22286, 75.078735]
# time:  4.764005422592163
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [570.1751, 541.51215, 526.0254]
# time:  1.4870891571044922
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [272.3335, 168.27505, 141.6964]
# time:  2.9840035438537598
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  28
# best_loss = [160.37267, 120.80699, 90.2874]
# time:  3.7600040435791016
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.72614, 544.4237, 528.9766]
# time:  1.5840020179748535
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.43494, 544.10504, 528.6274]
# time:  1.5880017280578613
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.7449, 543.2812, 527.7975]
# time:  1.5910015106201172
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.1041, 542.5274, 527.0694]
# time:  1.6420018672943115
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [165.33289, 118.51866, 75.717384]
# time:  7.7700090408325195
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [188.26894, 123.54475, 84.82492]
# time:  2.3020026683807373
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [252.93884, 179.8758, 130.70561]
# time:  19.03921866416931
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [244.84601, 156.27151, 116.490685]
# time:  3.34700345993042
#
#
#
# rnn = GRU, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  18
# best_loss = [184.02094, 125.31213, 79.86447]
# time:  3.113003730773926
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.11163, 543.7638, 528.2785]
# time:  1.408001184463501
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.0157, 543.65375, 528.1738]
# time:  1.4120018482208252
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.32574, 542.83234, 527.34406]
# time:  1.4120020866394043
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.3488, 544.00616, 528.53455]
# time:  1.4170010089874268
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [222.23499, 141.97548, 104.69993]
# time:  6.697661638259888
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.5419, 543.0637, 527.5778]
# time:  1.4260013103485107
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [278.33774, 210.70967, 161.43163]
# time:  16.20216393470764
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [230.14325, 162.34436, 119.8092]
# time:  4.365004777908325
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [227.63593, 137.68787, 88.98427]
# time:  1.998002290725708
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.5974, 544.27985, 528.8092]
# time:  1.5110018253326416
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.5144, 544.1923, 528.7135]
# time:  1.5030016899108887
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.82416, 543.366, 527.88324]
# time:  1.5110015869140625
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [562.1036, 520.0753, 508.51965]
# time:  4.143004655838013
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [241.49739, 162.31714, 120.192184]
# time:  4.667005300521851
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  46
# best_loss = [112.585335, 113.41732, 93.94461]
# time:  5.668006181716919
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  99
# best_loss = [259.57532, 187.20213, 125.008095]
# time:  10.980515956878662
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [236.86613, 148.68382, 106.190735]
# time:  3.02500319480896
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  14
# best_loss = [144.7833, 143.74396, 84.492584]
# time:  2.4230029582977295
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.99835, 543.5445, 528.05444]
# time:  1.5140016078948975
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [214.92532, 154.8595, 112.554955]
# time:  4.665005207061768
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  12
# best_loss = [207.15843, 147.96072, 92.5839]
# time:  2.2230024337768555
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.71686, 543.2544, 527.8344]
# time:  1.4970016479492188
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [221.46182, 141.25894, 109.74085]
# time:  4.592005252838135
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [156.98642, 155.17189, 79.596085]
# time:  2.9920032024383545
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.52234, 543.0455, 527.52423]
# time:  1.4920017719268799
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [268.31, 162.30832, 122.503]
# time:  3.0000033378601074
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  38
# best_loss = [109.08448, 127.225525, 87.38403]
# time:  4.770245552062988
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [562.9398, 521.4359, 509.63647]
# time:  4.353004693984985
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [223.73038, 156.69568, 104.02248]
# time:  4.894005537033081
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [162.91486, 128.28787, 77.1583]
# time:  3.1820034980773926
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  111
# best_loss = [248.40909, 181.58823, 124.63698]
# time:  13.29501485824585
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [229.88306, 143.89293, 94.14893]
# time:  3.305328845977783
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  31
# best_loss = [123.55872, 127.23851, 103.282906]
# time:  4.504005193710327
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  99
# best_loss = [245.25552, 175.32944, 106.5903]
# time:  12.196013927459717
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [237.65997, 150.06169, 107.13195]
# time:  3.360003709793091
#
#
#
# rnn = GRU, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  3
# best_loss = [239.34538, 169.53268, 94.556015]
# time:  1.4600014686584473
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.7577, 543.271, 527.79926]
# time:  1.4070017337799072
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [229.09772, 149.31541, 107.80027]
# time:  6.655007362365723
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [214.50215, 153.5126, 102.44971]
# time:  2.8180031776428223
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [264.88135, 195.49986, 150.96796]
# time:  16.07001805305481
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [252.05923, 163.07011, 122.194786]
# time:  2.8379671573638916
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  29
# best_loss = [149.43399, 121.96037, 70.82995]
# time:  3.660004138946533
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [557.99835, 515.25116, 503.89395]
# time:  3.867004156112671
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [261.33215, 169.14812, 110.60768]
# time:  2.838003396987915
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [141.698, 101.03897, 80.18065]
# time:  4.44600510597229
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  161
# best_loss = [280.7621, 209.17612, 166.21655]
# time:  17.057018995285034
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [222.59286, 150.36859, 107.11843]
# time:  5.785857915878296
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  46
# best_loss = [127.44156, 114.92166, 78.91656]
# time:  5.591399908065796
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  127
# best_loss = [270.92792, 188.52962, 144.03679]
# time:  13.797312259674072
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [240.00854, 149.34686, 107.53642]
# time:  3.0272889137268066
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [145.01553, 127.62422, 70.73747]
# time:  3.023003339767456
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  143
# best_loss = [256.25327, 172.7215, 112.236725]
# time:  15.380018472671509
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [244.37529, 153.30313, 101.42969]
# time:  3.0170021057128906
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  29
# best_loss = [120.82654, 107.37741, 87.14157]
# time:  3.920004367828369
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.6706, 543.2216, 527.73224]
# time:  1.5070021152496338
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [238.46806, 171.06232, 124.77428]
# time:  4.637004375457764
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  47
# best_loss = [104.91738, 111.30323, 80.00311]
# time:  5.728006839752197
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.6216, 544.30084, 528.8307]
# time:  1.4960017204284668
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.5411, 544.2164, 528.7421]
# time:  1.496001958847046
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.85095, 543.3948, 527.9122]
# time:  1.4950015544891357
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.5231, 544.1949, 528.7119]
# time:  1.4930016994476318
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.3798, 544.04364, 528.5676]
# time:  1.4910016059875488
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  66
# best_loss = [116.173706, 96.606384, 77.84516]
# time:  7.539008378982544
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  191
# best_loss = [237.38612, 181.30313, 139.23941]
# time:  21.240625381469727
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [237.61108, 151.97632, 112.10159]
# time:  3.1850030422210693
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  38
# best_loss = [120.298065, 99.96281, 66.20302]
# time:  5.069005966186523
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.55115, 544.23883, 528.77136]
# time:  1.6420018672943115
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.4812, 544.1522, 528.67737]
# time:  1.6410017013549805
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.79114, 543.3307, 527.8475]
# time:  1.6420018672943115
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [570.18066, 541.51227, 526.015]
# time:  1.675001859664917
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [231.29164, 168.42194, 106.04347]
# time:  6.462007284164429
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [151.10567, 119.429825, 76.77372]
# time:  3.341003894805908
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [559.4107, 517.15173, 505.28674]
# time:  3.7740042209625244
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  48
# best_loss = [232.59631, 154.86136, 103.002464]
# time:  5.455006122589111
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [208.5263, 146.99632, 95.886185]
# time:  2.844003438949585
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [571.85974, 543.452, 527.9376]
# time:  1.4370014667510986
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [241.21826, 165.93782, 126.41004]
# time:  4.3470048904418945
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  36
# best_loss = [144.63348, 113.50217, 76.12488]
# time:  4.349004745483398
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [545.5012, 501.6858, 489.18134]
# time:  3.8510043621063232
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [258.17477, 165.91394, 126.43885]
# time:  2.829003095626831
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [203.13171, 141.09418, 101.58846]
# time:  2.3550028800964355
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [556.8007, 514.8946, 501.9375]
# time:  4.1015074253082275
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [262.94363, 159.2339, 117.9664]
# time:  3.022003650665283
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [218.31306, 148.54271, 86.98512]
# time:  2.1010019779205322
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  162
# best_loss = [234.19208, 164.55104, 116.65114]
# time:  17.284019470214844
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [247.91466, 155.37755, 101.72777]
# time:  3.021003484725952
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [178.24232, 120.11669, 87.845024]
# time:  2.516002893447876
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  143
# best_loss = [251.07695, 170.51048, 121.41057]
# time:  15.36601734161377
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [248.7642, 159.91719, 113.45446]
# time:  3.0660033226013184
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  23
# best_loss = [128.02687, 129.00154, 92.8203]
# time:  3.4200496673583984
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [560.7604, 519.1859, 506.80414]
# time:  4.160004615783691
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [231.70639, 165.0608, 108.18724]
# time:  4.614350080490112
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  14
# best_loss = [193.96312, 159.11852, 115.67561]
# time:  2.4090027809143066
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  31
# best_loss = [560.6217, 518.81586, 506.9491]
# time:  4.081004619598389
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  36
# best_loss = [239.0164, 167.163, 123.744896]
# time:  4.588005065917969
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [217.60318, 139.18091, 95.265175]
# time:  2.977003335952759
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.41364, 544.0875, 528.61194]
# time:  1.4970016479492188
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  5
# best_loss = [572.3438, 544.0052, 528.5288]
# time:  1.4930016994476318
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  5
# best_loss = [571.6539, 543.18365, 527.699]
# time:  1.489001750946045
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  5
# best_loss = [572.19104, 543.8273, 528.25916]
# time:  1.5900015830993652
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  35
# best_loss = [202.63806, 155.83543, 111.02398]
# time:  4.781005620956421
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  20
# ...
# time:  52.20555591583252
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1909
# best_loss = [125.2399, 91.76045, 91.44136]
# time:  241.6930012702942
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  211
# best_loss = [122.0031, 100.335846, 72.1155]
# time:  71.32157754898071
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  29
# best_loss = [120.82654, 107.37741, 87.14157]
# time:  53.05240750312805
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  292
# best_loss = [234.6749, 137.87283, 118.35028]
# time:  79.23053312301636
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  962
# best_loss = [106.96689, 113.21564, 67.40166]
# time:  146.3278455734253
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  2252
# best_loss = [28.726463, 75.16864, 74.93347]
# time:  275.2039475440979
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1986
# best_loss = [574.28687, 527.04926, 522.21826]
# time:  246.82542300224304
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [534.2124, 477.29648, 470.19263]
# time:  297.4846701622009
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.53525, 200.05786, 168.67331]
# time:  297.70433354377747
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1986
# best_loss = [574.12756, 526.8716, 522.0431]
# time:  246.56890106201172
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [534.0594, 477.12128, 470.01855]
# time:  297.35240483283997
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  92
# best_loss = [103.27552, 88.00772, 72.257095]
# time:  58.59546089172363
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1684
# best_loss = [113.81021, 84.954834, 62.326004]
# time:  230.16832995414734
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  415
# best_loss = [87.60924, 91.06055, 69.44116]
# time:  96.28346562385559
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  314
# best_loss = [37.47799, 86.451935, 88.2233]
# time:  85.50782179832458
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1986
# best_loss = [574.22766, 526.98334, 522.1532]
# time:  271.21943163871765
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [534.1556, 477.2314, 470.12796]
# time:  327.06027936935425
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 5, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.53104, 200.05609, 168.66684]
# time:  327.12686109542847
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1209
# best_loss = [172.19553, 111.729195, 78.710205]
# time:  190.176274061203
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  445
# best_loss = [91.97655, 102.52978, 82.48007]
# time:  105.09479403495789
#
#
#
# rnn = RNN, bi = False, hid = 3, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  20
# best_loss = [151.10567, 119.429825, 76.77372]
# time:  57.844244718551636
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1142
# best_loss = [201.53015, 131.20811, 89.108154]
# time:  150.25115180015564
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  560
# best_loss = [92.4113, 102.327515, 83.08429]
# time:  97.28150081634521
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  308
# best_loss = [47.232986, 79.87876, 99.5466]
# time:  74.17208313941956
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1642
# best_loss = [147.57343, 110.587234, 97.277626]
# time:  197.27593636512756
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  392
# best_loss = [136.6417, 102.44283, 67.71523]
# time:  81.9080924987793
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  48
# best_loss = [141.67989, 108.44863, 87.265594]
# time:  50.350056886672974
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1543
# best_loss = [176.50064, 113.14286, 97.65096]
# time:  188.6620991230011
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  211
# best_loss = [155.12457, 87.953354, 64.30121]
# time:  65.77787351608276
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  29
# best_loss = [175.70045, 122.96295, 74.57251]
# time:  48.96409225463867
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Ends at final epoch 3000
# Best epoch: 2575
# best_loss = [122.30275, 87.506546, 74.3116]
# time:  293.0521328449249
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  362
# best_loss = [100.236824, 102.41033, 94.392715]
# time:  84.26530861854553
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  35
# best_loss = [122.94622, 143.37675, 89.998955]
# time:  52.33838701248169
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1400
# best_loss = [134.65117, 93.01687, 78.27674]
# time:  187.59811067581177
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  95
# best_loss = [150.9117, 114.11755, 89.0691]
# time:  58.723889112472534
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [178.24232, 120.11669, 87.845024]
# time:  50.86547327041626
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1212
# best_loss = [149.99895, 80.79704, 105.19639]
# time:  169.04697442054749
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  173
# best_loss = [124.475334, 91.93295, 93.595474]
# time:  66.43214678764343
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  23
# best_loss = [128.02687, 129.00154, 92.8203]
# time:  51.69453191757202
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  2339
# best_loss = [132.02393, 73.83093, 82.468414]
# time:  279.6043698787689
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  292
# best_loss = [121.69699, 86.60683, 86.96309]
# time:  78.07653450965881
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  945
# best_loss = [38.248238, 94.64726, 99.04154]
# time:  142.05998063087463
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  411
# best_loss = [234.45941, 138.55524, 113.05509]
# time:  89.05123257637024
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  648
# best_loss = [93.39041, 115.824745, 79.03159]
# time:  112.0995147228241
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  37
# best_loss = [150.9024, 122.71259, 86.70369]
# time:  52.58513426780701
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1142
# best_loss = [211.03702, 131.83093, 107.56334]
# time:  159.97775411605835
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [534.0252, 477.08215, 469.9797]
# time:  292.9399585723877
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.52112, 200.05188, 168.65158]
# time:  292.3240523338318
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1110
# best_loss = [134.43619, 95.803894, 108.98373]
# time:  166.90484166145325
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  765
# best_loss = [60.894547, 90.425, 105.02463]
# time:  131.32301902770996
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  780
# best_loss = [79.613815, 115.274704, 107.74437]
# time:  132.47659373283386
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  292
# best_loss = [212.79837, 127.93417, 101.48489]
# time:  85.12409567832947
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  20
# best_loss = [237.63011, 150.58064, 111.44914]
# time:  55.74053335189819
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [189.03732, 138.03326, 77.50806]
# time:  54.811659812927246
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  292
# best_loss = [216.89781, 132.38704, 102.76111]
# time:  86.67881727218628
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [213.9306, 140.80019, 98.13474]
# time:  61.44485807418823
#
#
#
# rnn = RNN, bi = False, hid = 5, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  21
# best_loss = [138.92464, 144.65747, 83.7529]
# time:  57.128214836120605
#
#
#
# Pooling: 1 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1144
# best_loss = [166.84074, 102.63741, 70.23922]
# time:  154.7157847881317
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  150
# best_loss = [131.39937, 111.750496, 65.59749]
# time:  61.20655798912048
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  47
# best_loss = [141.9299, 111.970985, 87.44501]
# time:  51.44427514076233
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  729
# best_loss = [157.52254, 108.21011, 82.38422]
# time:  116.09406638145447
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  101
# best_loss = [129.35135, 118.03745, 75.39453]
# time:  56.789063930511475
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  370
# best_loss = [45.161175, 105.29343, 107.00251]
# time:  82.22260212898254
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1986
# best_loss = [574.2119, 526.96564, 522.13586]
# time:  235.94354891777039
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [534.14044, 477.21405, 470.11072]
# time:  284.8174960613251
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.52994, 200.05562, 168.66513]
# time:  284.9492881298065
#
#
#
# Pooling: 1 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  411
# best_loss = [222.16087, 136.50151, 91.09892]
# time:  91.55324602127075
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  150
# best_loss = [143.892, 132.82977, 65.96435]
# time:  65.280588388443
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  1038
# best_loss = [24.124504, 119.159874, 67.52501]
# time:  154.6963198184967
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  557
# best_loss = [191.94409, 132.14912, 75.14909]
# time:  107.25239539146423
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  61
# best_loss = [199.92807, 136.08133, 75.891525]
# time:  56.935099363327026
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  19
# best_loss = [169.70508, 126.304756, 79.51383]
# time:  52.655378341674805
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  1144
# best_loss = [145.9102, 95.83324, 71.09584]
# time:  166.50655341148376
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  166
# best_loss = [122.62831, 119.58553, 67.245544]
# time:  67.39042282104492
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  15
# best_loss = [144.7085, 123.267784, 76.52396]
# time:  52.2353618144989
#
#
#
# Pooling: 2 layers, Nonpooling: 1 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1651
# best_loss = [139.51164, 100.37927, 69.551285]
# time:  217.488915681839
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Early stopping at best epoch:  144
# best_loss = [167.69466, 123.06452, 87.99955]
# time:  65.11250042915344
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Early stopping at best epoch:  311
# best_loss = [40.990177, 115.17295, 96.93381]
# time:  81.94676685333252
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1186
# best_loss = [159.21683, 114.39038, 54.84886]
# time:  169.08733344078064
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [533.7206, 476.73328, 469.63312]
# time:  300.4521608352661
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.49805, 200.04214, 168.61604]
# time:  300.4821193218231
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  729
# best_loss = [176.38628, 136.30743, 82.43255]
# time:  123.01705622673035
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  166
# best_loss = [146.64627, 134.0448, 60.435226]
# time:  66.76261949539185
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  31
# best_loss = [133.82143, 105.49716, 71.75553]
# time:  53.08658289909363
#
#
#
# Pooling: 2 layers, Nonpooling: 2 layers, split by 0.5 min
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.0001
# Early stopping at best epoch:  1986
# best_loss = [573.8257, 526.535, 521.711]
# time:  264.608172416687
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.001
# Ends at final epoch 3000
# Best epoch: 2780
# best_loss = [533.7693, 476.78903, 469.68848]
# time:  319.1859395503998
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 3, lr = 0.01
# Ends at final epoch 3000
# Best epoch: 2955
# best_loss = [288.5016, 200.04362, 168.62146]
# time:  318.505051612854
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.0001
# Early stopping at best epoch:  1394
# best_loss = [134.48709, 112.592285, 60.478195]
# time:  208.50063371658325
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.001
# Early stopping at best epoch:  921
# best_loss = [42.234406, 69.944336, 103.59474]
# time:  156.37430953979492
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 5, lr = 0.01
# Early stopping at best epoch:  358
# best_loss = [43.730446, 118.2232, 97.108246]
# time:  94.45598363876343
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.0001
# Early stopping at best epoch:  411
# best_loss = [168.5676, 112.79857, 76.55082]
# time:  102.14549541473389
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.001
# Early stopping at best epoch:  113
# best_loss = [126.34005, 119.61225, 79.76642]
# time:  68.79361152648926
#
#
#
# rnn = RNN, bi = False, hid = 7, num_fil = 7, lr = 0.01
# Early stopping at best epoch:  11
# best_loss = [164.64622, 115.760826, 81.84608]
# time:  57.38333868980408
